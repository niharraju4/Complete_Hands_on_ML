# %%
# IMPORT LIBRARIERS
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
lifesat = pd.read_csv(r'N:\Personal_Projects\HandsonML\data-main\data-main\lifesat\lifesat.csv')

# %%
lifesat
# Out:
#            Country  GDP per capita (USD)  Life satisfaction
# 0           Russia          26456.387938                5.8
# 1           Greece          27287.083401                5.4
# 2           Turkey          28384.987785                5.5
# 3           Latvia          29932.493910                5.9
# 4          Hungary          31007.768407                5.6
# 5         Portugal          32181.154537                5.4
# 6           Poland          32238.157259                6.1
# 7          Estonia          35638.421351                5.7
# 8            Spain          36215.447591                6.3
# 9         Slovenia          36547.738956                5.9
# 10       Lithuania          36732.034744                5.9
# 11          Israel          38341.307570                7.2
# 12           Italy          38992.148381                6.0
# 13  United Kingdom          41627.129269                6.8
# 14          France          42025.617373                6.5
# ...

# %%
X = lifesat[["GDP per capita (USD)"]].values
y= lifesat[["Life satisfaction"]].values

# %%
lifesat.plot(kind='scatter', grid=True,
             x="GDP per capita (USD)",y="Life satisfaction")
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# Ensure X and y have the same number of samples
X = lifesat[["GDP per capita (USD)"]].values
y = lifesat["Life satisfaction"].values

# Select a linear model
model = LinearRegression()

# Fit the model
model.fit(X, y)

# Predict for a new data point
X_new = [[37_655.2]]  # Cyprus' GDP per capita in 2020
print(model.predict(X_new))
# Out:
# [6.30165767]

# %% [markdown]
# Replacing the Linear Regression model with k-Nearest Neighbors (in this example, k = 3) regression in the previous code is as simple as replacing these two lines:

# %%
# Select a 3-Nearest Neighbors regression model
from sklearn.neighbors import KNeighborsRegressor

model = KNeighborsRegressor(n_neighbors=3)

# Train the model
model.fit(X, y)

# Make a prediction for Cyprus
print(model.predict(X_new)) # outputs [[6.33333333]]
# Out:
# [6.33333333]

# %%
gdp_per_capita = pd.read_csv(r'N:\Personal_Projects\HandsonML\data-main\data-main\lifesat\gdp_per_capita.csv')

# %%
gdp_per_capita.head()
# Out:
#         Entity Code  Year  GDP per capita, PPP (constant 2017 international $)
# 0  Afghanistan  AFG  2002                                        1189.784668
# 1  Afghanistan  AFG  2003                                        1235.810063
# 2  Afghanistan  AFG  2004                                        1200.278013
# 3  Afghanistan  AFG  2005                                        1286.793659
# 4  Afghanistan  AFG  2006                                        1315.789117

# %%
print(gdp_per_capita.columns)
# Out:
# Index(['Entity', 'Code', 'Year',
#        'GDP per capita, PPP (constant 2017 international $)'],
#       dtype='object')

# %%
gdp_year= 2020
gdppc_Col ="GDP per capita (USD)"
life_col ="Life satisfaction"

# %%
gdp_per_capita = gdp_per_capita[gdp_per_capita["Year"]==gdp_year]

# %%
gdp_per_capita.drop(columns=["Code","Year"], inplace=True, axis=1)
gdp_per_capita
# Out:
#                            Entity  \
# 18                    Afghanistan
# 49    Africa Eastern and Southern
# 80     Africa Western and Central
# 111                       Albania
# 142                       Algeria
# ...                           ...
# 6984                      Vanuatu
# 7015                      Vietnam
# 7046                        World
# 7077                       Zambia
# 7108                     Zimbabwe
#
#       GDP per capita, PPP (constant 2017 international $)
# 18                                          1978.961579
# 49                                          3387.594670
# 80                                          4003.158913
# 111                                        13295.410885
# 142                                        10681.679297
# ...                                                 ...
# 6984                                        2762.791388
# 7015                                        8200.331867
# ...

# %%
gdp_per_capita.columns=["Country", gdppc_Col]
gdp_per_capita.set_index("Country", inplace=True)
gdp_per_capita.head()
# Out:
#                              GDP per capita (USD)
# Country
# Afghanistan                           1978.961579
# Africa Eastern and Southern           3387.594670
# Africa Western and Central            4003.158913
# Albania                              13295.410885
# Algeria                              10681.679297
